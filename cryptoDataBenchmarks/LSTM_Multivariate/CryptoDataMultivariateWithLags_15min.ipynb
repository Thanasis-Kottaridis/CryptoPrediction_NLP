# %%
# Basic Imports
import sys
sys.path.insert(1, "../../")

import utils
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.metrics import mean_squared_error

# Imports for data preprocessing.
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Tensorflow imports
import tensorflow as tf

# %%
# Disable GPU
tf.config.set_visible_devices([], 'GPU')

# %%
# Constants
DATA_FILE_NAME = '../../Data/final_crypto_data.csv'
SELECTED_MONTHS = [10,11,12,1,2,3]
SELECTED_FEATURES = [
        'reddit_compound_polarity',
		# 'quote_volume_24h',
        # 'volume_change_24h',
        # 'percent_change_1h',
        # 'percent_change_24h',
        # 'percent_change_7d',
		# 'high_24h',
        # 'last_24h',
        # 'bid_24h',
        # 'vwap_24h',
        # 'volume_24h',
        # 'low_24h',
        # 'ask_24h',
        # 'open_24h',
        'volume_1min',
        'high_1min',
        'low_1min',
        'open_1min',
        'close_1min'
    ]

# %%
df = pd.read_csv(DATA_FILE_NAME)
df = df[::15]
df
# Out:
#         Unnamed: 0                       _id  high_24h  last_24h  \
# 0                0  627127fabbd592fa2c7f25a9  62971.54  62561.13
# 15              15  627127fabbd592fa2c7f25b8  62971.54  62541.28
# 30              30  627127fabbd592fa2c7f25c7  62971.54  62505.02
# 45              45  627127fabbd592fa2c7f25d6  62971.54  62385.18
# 60              60  627127fabbd592fa2c7f25e5  62971.54  62397.10
# ...            ...                       ...       ...       ...
# 246720      246720  62712800bbd592fa2c82e969  38786.95  38414.87
# 246735      246735  62712800bbd592fa2c82e978  38786.95  38445.18
# 246750      246750  62712800bbd592fa2c82e987  38786.95  38384.58
# 246765      246765  62712800bbd592fa2c82e996  38786.95  38351.20
# 246780      246780  62712800bbd592fa2c82e9a5  38786.95  38284.40
#
#         unix_timestamp   bid_24h  vwap_24h   volume_24h  low_24h   ask_24h  \
# 0           1635527368  62559.74  60908.08  5113.537402  56425.0  62561.13
# 15          1635527731  62531.62  60915.95  5121.220901  56425.0  62550.96
# 30          1635529300  62496.24  60950.29  5200.503262  56425.0  62502.94
# 45          1635530148  62384.03  60959.83  5218.017958  56425.0  62399.55
# 60          1635530994  62394.14  60962.99  5204.297994  56425.0  62404.25
# ...                ...       ...       ...          ...      ...       ...
# 246720      1651348288  38382.42  38519.83   594.586166  38160.4  38407.03
# 246735      1651349318  38431.28  38539.51   563.808424  38160.4  38445.72
# 246750      1651350349  38370.64  38540.97   566.041421  38160.4  38384.58
# 246765      1651351078  38331.79  38540.81   566.041421  38160.4  38350.37
# 246780      1651351986  38286.98  38540.09   566.041421  38160.4  38304.01
#
#         ...  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0       ...          -0.314446            2.307206           2.108769
# 15      ...          -0.366133            2.361134           2.388851
# 30      ...          -0.021597            2.406680           2.941529
# 45      ...          -0.543703            2.119603           2.870641
# 60      ...          -0.280623            1.947506           2.811090
# ...     ...                ...                 ...                ...
# 246720  ...           0.270777            0.247061          -3.430754
# 246735  ...           0.232198            0.148902          -3.406210
# 246750  ...           0.135730           -0.319612          -3.488027
# 246765  ...           0.002831           -0.417371          -3.630196
# 246780  ...          -0.122146           -0.504882          -3.631748
#
#         percent_change_30d  percent_change_60d  percent_change_90d  \
# 0                26.873643           29.933036           49.972913
# 15               26.873643           29.945589           49.972913
# 30               26.873643           29.810102           49.972913
# 45               26.873643           29.471630           49.972913
# 60               26.873643           29.034676           49.972913
# ...                    ...                 ...                 ...
# 246720          -16.083945          -12.392731            2.109056
# 246735          -15.717118          -12.409961            2.722041
# 246750          -16.027128          -12.412714            1.877778
# 246765          -16.079912          -12.589880            1.793039
# 246780          -16.229210          -12.655589            1.853657
#
#           market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0       1.179682e+12               43.4826              1.313676e+12
# 15      1.179410e+12               43.4826              1.313374e+12
# 30      1.179112e+12               43.4826              1.313041e+12
# 45      1.176056e+12               43.4826              1.309639e+12
# 60      1.176295e+12               43.4826              1.309904e+12
# ...              ...                   ...                       ...
# 246720  7.302011e+11               42.0843              8.059303e+11
# 246735  7.317070e+11               42.0415              8.075924e+11
# 246750  7.305612e+11               42.0036              8.063239e+11
# 246765  7.299792e+11               42.0415              8.056816e+11
# 246780  7.298298e+11               42.0580              8.055168e+11
#
#         reddit_compound_polarity
# 0                       0.000834
# 15                      0.000834
# 30                      0.123475
# 45                      0.262691
# 60                      0.044513
# ...                          ...
# 246720                  0.190067
# 246735                  0.401900
# 246750                 -0.171560
# 246765                 -0.096760
# 246780                  0.000800
#
# [16453 rows x 32 columns]

# %%
# Drop unnecessary columns
df = utils.setDateTimeAsIndex(df)
df = utils.filterColumns(df, SELECTED_FEATURES)
df = utils.filterInMonths(df, SELECTED_MONTHS)
df
# Out:
#                      reddit_compound_polarity  volume_1min  high_1min  \
# datetime
# 2021-10-29 17:09:28                  0.000834     1.425169   62565.90
# 2021-10-29 17:15:31                  0.000834     1.382506   62554.21
# 2021-10-29 17:41:40                  0.123475     0.299922   62552.18
# 2021-10-29 17:55:48                  0.262691     0.104318   62397.39
# 2021-10-29 18:09:54                  0.044513     3.846862   62407.86
# ...                                       ...          ...        ...
# 2022-03-29 13:49:57                  0.159400     4.127755   47674.37
# 2022-03-29 14:03:04                  0.567486     0.007683   47744.40
# 2022-03-29 14:20:16                  0.598674     0.002850   47708.53
# 2022-03-29 14:33:28                  0.411539     0.998933   47850.25
# 2022-03-29 14:48:36                 -0.038386     0.030004   47874.67
#
#                      low_1min  open_1min  close_1min
# datetime
# 2021-10-29 17:09:28  62539.20   62545.45    62561.86
# 2021-10-29 17:15:31  62486.12   62513.02    62531.42
# 2021-10-29 17:41:40  62505.02   62552.18    62516.47
# 2021-10-29 17:55:48  62366.89   62397.39    62385.18
# 2021-10-29 18:09:54  62368.24   62385.41    62397.57
# ...                       ...        ...         ...
# 2022-03-29 13:49:57  47597.27   47657.99    47603.68
# 2022-03-29 14:03:04  47744.40   47744.40    47744.40
# 2022-03-29 14:20:16  47708.53   47708.53    47708.53
# 2022-03-29 14:33:28  47799.42   47850.25    47799.42
# 2022-03-29 14:48:36  47848.03   47848.03    47874.67
#
# [13771 rows x 6 columns]

# %%
# check for null values per column
print("NaN values per column count: \n")
df.isna().sum()
# Out:
# NaN values per column count:
# reddit_compound_polarity    0
# volume_1min                 0
# high_1min                   0
# low_1min                    0
# open_1min                   0
# close_1min                  0
# dtype: int64

# %%
values = df.values
i = 1

# %%
# plot each column
plt.figure(figsize=(15,9))
for group in range(len(SELECTED_FEATURES)) :
	plt.subplot(len(SELECTED_FEATURES), 1, i)
	plt.plot(values[:, group])
	plt.title(df.columns[group], y=0.5, loc='right')
	i += 1
plt.show()

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True, doPrints=False):
	"""
	:param data: Ta data pou theloume na metasximatisoume se numpy Array
	:param n_in: to plithos ton Lags pou tha exei i input series (X)
	:param n_out: to plithos ton Lags pou tha exei i output series (y)
	:param dropnan: ama theloume na kanoume drop ta nan valuws
	:return: epistrefei tin metasximatismeni lista se multivariate time series.
	"""

	# vreiskei to n_vars
	# an ta data einai list = 1
	# alliws pernei to shape ton data.
	n_vars = 1 if type(data) is list else data.shape[1]

	# kanoume ta data DataFrame
	mDf = pd.DataFrame(data)
	if doPrints:
		print(mDf)

	# ftiaxnei 2 adies listes. mia fia ta
	cols, names = list(), list()
	if doPrints:
		print(n_vars)

	# ftiaxnoume to input series X. (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		# kanoume append sto cols to dataframe olistimeno kata i rows
		cols.append(mDf.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

	# ftiaxnoume to forecast sequence y (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(mDf.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

	if doPrints:
		print(cols)
		print(names)

	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# get dataframe values.
values = df.values
values
# Out:
# array([[ 8.33660422e-04,  1.42516865e+00,  6.25659000e+04,
#          6.25392000e+04,  6.25454500e+04,  6.25618600e+04],
#        [ 8.34156501e-04,  1.38250593e+00,  6.25542100e+04,
#          6.24861200e+04,  6.25130200e+04,  6.25314200e+04],
#        [ 1.23475000e-01,  2.99922230e-01,  6.25521800e+04,
#          6.25050200e+04,  6.25521800e+04,  6.25164700e+04],
#        ...,
#        [ 5.98673783e-01,  2.85000000e-03,  4.77085300e+04,
#          4.77085300e+04,  4.77085300e+04,  4.77085300e+04],
#        [ 4.11538759e-01,  9.98932800e-01,  4.78502500e+04,
#          4.77994200e+04,  4.78502500e+04,  4.77994200e+04],
#        [-3.83863363e-02,  3.00040000e-02,  4.78746700e+04,
#          4.78480300e+04,  4.78480300e+04,  4.78746700e+04]])

# %%
# Ensure all data are float.
values = values.astype('float32')
values
# Out:
# array([[ 8.3366042e-04,  1.4251686e+00,  6.2565898e+04,  6.2539199e+04,
#          6.2545449e+04,  6.2561859e+04],
#        [ 8.3415653e-04,  1.3825059e+00,  6.2554211e+04,  6.2486121e+04,
#          6.2513020e+04,  6.2531422e+04],
#        [ 1.2347500e-01,  2.9992223e-01,  6.2552180e+04,  6.2505020e+04,
#          6.2552180e+04,  6.2516469e+04],
#        ...,
#        [ 5.9867376e-01,  2.8500000e-03,  4.7708531e+04,  4.7708531e+04,
#          4.7708531e+04,  4.7708531e+04],
#        [ 4.1153875e-01,  9.9893278e-01,  4.7850250e+04,  4.7799422e+04,
#          4.7850250e+04,  4.7799422e+04],
#        [-3.8386337e-02,  3.0004000e-02,  4.7874672e+04,  4.7848031e+04,
#          4.7848031e+04,  4.7874672e+04]], dtype=float32)

# %%
# Normalize Continues Features.
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_values = scaler.fit_transform(values)
scaled_values
# Out:
# array([[4.9725229e-01, 2.7734685e-01, 9.2514467e-01, 9.2489862e-01,
#         9.2472172e-01, 9.2534935e-01],
#        [4.9725255e-01, 2.6904443e-01, 9.2472863e-01, 9.2300916e-01,
#         9.2356730e-01, 9.2426574e-01],
#        [5.6205505e-01, 5.8366768e-02, 9.2465639e-01, 9.2368197e-01,
#         9.2496133e-01, 9.2373335e-01],
#        ...,
#        [8.1314653e-01, 5.5462809e-04, 3.9624119e-01, 3.9697123e-01,
#         3.9652598e-01, 3.9657569e-01],
#        [7.1426582e-01, 1.9439866e-01, 4.0128624e-01, 4.0020669e-01,
#         4.0157127e-01, 3.9981139e-01],
#        [4.7652873e-01, 5.8389688e-03, 4.0215564e-01, 4.0193701e-01,
#         4.0149224e-01, 4.0249026e-01]], dtype=float32)

# %%
# specify the number of lag hours
n_hours = 10
n_features = len(SELECTED_FEATURES)
n_obs = n_hours * n_features

# %%
# prepare data for lstm
reframed = series_to_supervised(scaled_values, n_in=n_hours,n_out=1)
reframed
# Out:
#        var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  \
# 10       0.497252    0.277347    0.925145    0.924899    0.924722    0.925349
# 11       0.497253    0.269044    0.924729    0.923009    0.923567    0.924266
# 12       0.562055    0.058367    0.924656    0.923682    0.924961    0.923733
# 13       0.635616    0.020301    0.919146    0.918765    0.919451    0.919060
# 14       0.520332    0.748624    0.919519    0.918813    0.919024    0.919501
# ...           ...         ...         ...         ...         ...         ...
# 13766    0.496812    0.005746    0.395414    0.395010    0.395309    0.394614
# 13767    0.496812    0.000111    0.397069    0.397799    0.397354    0.397404
# 13768    0.378639    0.776665    0.402564    0.402713    0.402393    0.402634
# 13769    0.709173    0.950032    0.404454    0.403806    0.403362    0.403925
# 13770    0.697995    0.000000    0.405905    0.406635    0.406190    0.406240
#
#        var1(t-9)  var2(t-9)  var3(t-9)  var4(t-9)  ...  var3(t-1)  var4(t-1)  \
# 10      0.497253   0.269044   0.924729   0.923009  ...   0.908559   0.907062
# 11      0.562055   0.058367   0.924656   0.923682  ...   0.910937   0.909406
# 12      0.635616   0.020301   0.919146   0.918765  ...   0.915296   0.914989
# 13      0.520332   0.748624   0.919519   0.918813  ...   0.918561   0.917818
# 14      0.497046   0.080173   0.912844   0.912877  ...   0.920304   0.919888
# ...          ...        ...        ...        ...  ...        ...        ...
# 13766   0.496812   0.000111   0.397069   0.397799  ...   0.404000   0.403399
# 13767   0.378639   0.776665   0.402564   0.402713  ...   0.395025   0.393011
# 13768   0.709173   0.950032   0.404454   0.403806  ...   0.397518   0.398248
# 13769   0.697995   0.000000   0.405905   0.406635  ...   0.396241   0.396971
# 13770   0.717571   0.002339   0.407277   0.408007  ...   0.401286   0.400207
#
#        var5(t-1)  var6(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 10      0.907396   0.906705  0.525537  0.116531  0.910937  0.909406  0.910196
# 11      0.910196   0.909145  0.520404  0.021735  0.915296  0.914989  0.915166
# 12      0.915166   0.915644  0.496812  0.103682  0.918561  0.917818  0.918865
# 13      0.918865   0.918685  0.496812  0.090374  0.920304  0.919888  0.919854
# 14      0.919854   0.920652  0.496812  0.015209  0.922883  0.922146  0.923188
# ...          ...        ...       ...       ...       ...       ...       ...
# 13766   0.403546   0.403004  0.581038  0.803287  0.395025  0.393011  0.394727
# 13767   0.394727   0.392843  0.796667  0.001495  0.397518  0.398248  0.397803
# 13768   0.397803   0.397853  0.813147  0.000555  0.396241  0.396971  0.396526
# 13769   0.396526   0.396576  0.714266  0.194399  0.401286  0.400207  0.401571
# 13770   0.401571   0.399811  0.476529  0.005839  0.402156  0.401937  0.401492
#
#         var6(t)
# 10     0.909145
# 11     0.915644
# 12     0.918685
# 13     0.920652
# 14     0.921789
# ...         ...
# 13766  0.392843
# 13767  0.397853
# 13768  0.396576
# 13769  0.399811
# 13770  0.402490
#
# [13761 rows x 66 columns]

# %%
def train_test_valid_split(total_x, total_y, train_size=0.8, valid_size=0.1) :
    train_index = int(len(total_x) * train_size)
    valid_index = int(len(total_x) * valid_size)

    X_train, y_train = total_x[0 :train_index], total_y[0 :train_index]
    X_valid, y_valid = total_x[train_index :train_index + valid_index], total_y[train_index :train_index + valid_index]
    X_test, y_test = total_x[train_index + valid_index :], total_y[train_index + valid_index :]

    print("-------- train test valid split --------")
    print(len(X_train)), print(len(y_train))
    print(len(X_valid)), print(len(y_valid))
    print(len(X_test)), print(len(y_test))
    print("----------------------------------------")

    return np.array(X_train), \
           np.array(y_train), \
           np.array(X_valid), \
           np.array(y_valid), \
           np.array(X_test), \
           np.array(y_test)

# %%
# split into train and test sets
values = reframed.values
# cutoff = round(0.70 * len(values))
# values = values[cutoff:,:]
values
# Out:
# array([[0.4972523 , 0.27734685, 0.9251447 , ..., 0.9094062 , 0.9101958 ,
#         0.909145  ],
#        [0.49725255, 0.26904443, 0.92472863, ..., 0.9149885 , 0.9151664 ,
#         0.9156438 ],
#        [0.56205505, 0.05836677, 0.9246564 , ..., 0.9178183 , 0.9188652 ,
#         0.9186851 ],
#        ...,
#        [0.37863904, 0.7766648 , 0.40256393, ..., 0.39697123, 0.39652598,
#         0.3965757 ],
#        [0.7091727 , 0.9500315 , 0.4044541 , ..., 0.40020669, 0.40157127,
#         0.3998114 ],
#        [0.6979947 , 0.        , 0.40590513, ..., 0.401937  , 0.40149224,
#         0.40249026]], dtype=float32)

# %%
X =  values[:,:n_obs]
X
# Out:
# array([[0.4972523 , 0.27734685, 0.9251447 , ..., 0.9070623 , 0.9073963 ,
#         0.906705  ],
#        [0.49725255, 0.26904443, 0.92472863, ..., 0.9094062 , 0.9101958 ,
#         0.909145  ],
#        [0.56205505, 0.05836677, 0.9246564 , ..., 0.9149885 , 0.9151664 ,
#         0.9156438 ],
#        ...,
#        [0.37863904, 0.7766648 , 0.40256393, ..., 0.39824808, 0.39780295,
#         0.39785254],
#        [0.7091727 , 0.9500315 , 0.4044541 , ..., 0.39697123, 0.39652598,
#         0.3965757 ],
#        [0.6979947 , 0.        , 0.40590513, ..., 0.40020669, 0.40157127,
#         0.3998114 ]], dtype=float32)

# %%
y = values[:,-1]
y
# Out:
# array([0.909145  , 0.9156438 , 0.9186851 , ..., 0.3965757 , 0.3998114 ,
#        0.40249026], dtype=float32)

# %%
train_X, train_y, valid_X, valid_y, test_X, test_y = train_test_valid_split(
	X,
	y,
	train_size=0.8,
	valid_size=0.1
)
print("----------------------------")
print(f"-------- Train X: {train_X.shape}, Train y: {train_y.shape} --------")
print(f"-------- Valid X: {valid_X.shape}, Valid y: {valid_y.shape} --------")
print(f"-------- Test X: {test_X.shape}, Test y: {test_y.shape} --------")
print("----------------------------\n")
# Out:
# -------- train test valid split --------
# 11008
# 11008
# 1376
# 1376
# 1377
# 1377
# ----------------------------------------
# ----------------------------
# -------- Train X: (11008, 60), Train y: (11008,) --------
# -------- Valid X: (1376, 60), Valid y: (1376,) --------
# -------- Test X: (1377, 60), Test y: (1377,) --------
# ----------------------------

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Minute Observations')
plt.ylabel('Closing Price')
plt.plot(df['close_1min'][:len(train_y)], 'green', label='Train data')
plt.plot(df['close_1min'][len(train_y):len(train_y)+len(valid_y)], 'blue', label='Validation data')
plt.plot(df['close_1min'][len(train_y)+len(valid_y):], 'orange', label='Test data')
plt.legend()

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
valid_X = valid_X.reshape((valid_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, valid_X.shape, valid_y.shape)
# Out:
# (11008, 10, 6) (11008,) (1376, 10, 6) (1376,)

# %%
 # Network Configurations
EPOCHS = 100
BATCH_SIZE = 128

# %%
# design network
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(
	128,
	# return_sequences=True,
	# activation='relu',
	# unroll=True,
	input_shape=(train_X.shape[1], train_X.shape[2]),
))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.LSTM(
# 	32,
# 	activation='relu',
# 	# unroll=True,
# ))
# model.add(Dropout(0.2))
# model.add(Dense(BATCH_SIZE))
# model.add(tf.keras.layers.Dense(8))
# model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit network
history = model.fit(
	train_X,
	train_y,
	epochs=EPOCHS,
	batch_size=BATCH_SIZE,
	validation_data=(valid_X, valid_y),
	verbose=2,
	shuffle=False
)
# Out:
# Epoch 1/100
# 2023-01-15 15:57:32.746159: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 86/86 - 2s - loss: 0.0148 - val_loss: 8.9064e-04 - 2s/epoch - 21ms/step
# Epoch 2/100
# 86/86 - 1s - loss: 0.0031 - val_loss: 2.9972e-04 - 903ms/epoch - 10ms/step
# Epoch 3/100
# 86/86 - 1s - loss: 0.0015 - val_loss: 1.5825e-04 - 930ms/epoch - 11ms/step
# Epoch 4/100
# 86/86 - 1s - loss: 8.6729e-04 - val_loss: 1.4502e-04 - 914ms/epoch - 11ms/step
# Epoch 5/100
# 86/86 - 1s - loss: 7.7540e-04 - val_loss: 1.3946e-04 - 925ms/epoch - 11ms/step
# Epoch 6/100
# 86/86 - 1s - loss: 8.0476e-04 - val_loss: 1.3566e-04 - 908ms/epoch - 11ms/step
# Epoch 7/100
# 86/86 - 1s - loss: 8.3975e-04 - val_loss: 1.3126e-04 - 897ms/epoch - 10ms/step
# Epoch 8/100
# 86/86 - 1s - loss: 8.6450e-04 - val_loss: 1.2578e-04 - 908ms/epoch - 11ms/step
# Epoch 9/100
# 86/86 - 1s - loss: 8.7967e-04 - val_loss: 1.1949e-04 - 916ms/epoch - 11ms/step
# Epoch 10/100
# 86/86 - 1s - loss: 8.8917e-04 - val_loss: 1.1294e-04 - 897ms/epoch - 10ms/step
# Epoch 11/100
# 86/86 - 1s - loss: 8.9643e-04 - val_loss: 1.0648e-04 - 899ms/epoch - 10ms/step
# Epoch 12/100
# 86/86 - 1s - loss: 9.0419e-04 - val_loss: 1.0050e-04 - 898ms/epoch - 10ms/step
# Epoch 13/100
# 86/86 - 1s - loss: 9.1502e-04 - val_loss: 9.5108e-05 - 898ms/epoch - 10ms/step
# Epoch 14/100
# 86/86 - 1s - loss: 9.3210e-04 - val_loss: 9.0452e-05 - 900ms/epoch - 10ms/step
# Epoch 15/100
# 86/86 - 1s - loss: 9.5737e-04 - val_loss: 8.6460e-05 - 898ms/epoch - 10ms/step
# Epoch 16/100
# 86/86 - 1s - loss: 9.9651e-04 - val_loss: 8.3105e-05 - 917ms/epoch - 11ms/step
# Epoch 17/100
# 86/86 - 1s - loss: 0.0011 - val_loss: 8.0287e-05 - 902ms/epoch - 10ms/step
# Epoch 18/100
# 86/86 - 1s - loss: 0.0011 - val_loss: 7.7954e-05 - 901ms/epoch - 10ms/step
# Epoch 19/100
# 86/86 - 1s - loss: 0.0012 - val_loss: 7.5913e-05 - 923ms/epoch - 11ms/step
# Epoch 20/100
# 86/86 - 1s - loss: 0.0014 - val_loss: 7.4451e-05 - 903ms/epoch - 10ms/step
# Epoch 21/100
# 86/86 - 1s - loss: 0.0016 - val_loss: 7.3100e-05 - 894ms/epoch - 10ms/step
# Epoch 22/100
# 86/86 - 1s - loss: 0.0019 - val_loss: 7.2939e-05 - 893ms/epoch - 10ms/step
# Epoch 23/100
# 86/86 - 1s - loss: 0.0017 - val_loss: 7.4620e-05 - 898ms/epoch - 10ms/step
# Epoch 24/100
# 86/86 - 1s - loss: 0.0021 - val_loss: 7.2462e-05 - 903ms/epoch - 10ms/step
# Epoch 25/100
# 86/86 - 1s - loss: 0.0023 - val_loss: 7.4676e-05 - 911ms/epoch - 11ms/step
# Epoch 26/100
# 86/86 - 1s - loss: 0.0028 - val_loss: 7.2714e-05 - 894ms/epoch - 10ms/step
# Epoch 27/100
# 86/86 - 1s - loss: 0.0029 - val_loss: 6.9964e-05 - 887ms/epoch - 10ms/step
# Epoch 28/100
# 86/86 - 1s - loss: 0.0036 - val_loss: 7.4652e-05 - 885ms/epoch - 10ms/step
# Epoch 29/100
# 86/86 - 1s - loss: 0.0046 - val_loss: 6.8861e-05 - 896ms/epoch - 10ms/step
# Epoch 30/100
# 86/86 - 1s - loss: 0.0051 - val_loss: 6.6054e-05 - 896ms/epoch - 10ms/step
# Epoch 31/100
# 86/86 - 1s - loss: 0.0056 - val_loss: 8.9194e-05 - 882ms/epoch - 10ms/step
# Epoch 32/100
# 86/86 - 1s - loss: 0.0058 - val_loss: 8.5548e-05 - 885ms/epoch - 10ms/step
# Epoch 33/100
# 86/86 - 1s - loss: 0.0054 - val_loss: 8.1715e-05 - 883ms/epoch - 10ms/step
# Epoch 34/100
# 86/86 - 1s - loss: 0.0050 - val_loss: 7.5893e-05 - 882ms/epoch - 10ms/step
# Epoch 35/100
# 86/86 - 1s - loss: 0.0047 - val_loss: 7.7703e-05 - 883ms/epoch - 10ms/step
# Epoch 36/100
# 86/86 - 1s - loss: 0.0041 - val_loss: 7.2648e-05 - 905ms/epoch - 11ms/step
# Epoch 37/100
# 86/86 - 1s - loss: 0.0036 - val_loss: 7.2391e-05 - 898ms/epoch - 10ms/step
# Epoch 38/100
# 86/86 - 1s - loss: 0.0032 - val_loss: 6.5981e-05 - 890ms/epoch - 10ms/step
# Epoch 39/100
# 86/86 - 1s - loss: 0.0028 - val_loss: 6.2498e-05 - 890ms/epoch - 10ms/step
# Epoch 40/100
# 86/86 - 1s - loss: 0.0025 - val_loss: 5.8384e-05 - 896ms/epoch - 10ms/step
# Epoch 41/100
# 86/86 - 1s - loss: 0.0022 - val_loss: 5.4818e-05 - 890ms/epoch - 10ms/step
# Epoch 42/100
# 86/86 - 1s - loss: 0.0020 - val_loss: 5.2029e-05 - 892ms/epoch - 10ms/step
# Epoch 43/100
# 86/86 - 1s - loss: 0.0018 - val_loss: 4.9996e-05 - 889ms/epoch - 10ms/step
# Epoch 44/100
# 86/86 - 1s - loss: 0.0017 - val_loss: 4.8577e-05 - 885ms/epoch - 10ms/step
# Epoch 45/100
# 86/86 - 1s - loss: 0.0016 - val_loss: 4.7650e-05 - 899ms/epoch - 10ms/step
# Epoch 46/100
# 86/86 - 1s - loss: 0.0015 - val_loss: 4.7080e-05 - 892ms/epoch - 10ms/step
# Epoch 47/100
# 86/86 - 1s - loss: 0.0014 - val_loss: 4.6692e-05 - 891ms/epoch - 10ms/step
# Epoch 48/100
# 86/86 - 1s - loss: 0.0013 - val_loss: 4.6368e-05 - 897ms/epoch - 10ms/step
# Epoch 49/100
# 86/86 - 1s - loss: 0.0013 - val_loss: 4.5995e-05 - 897ms/epoch - 10ms/step
# Epoch 50/100
# 86/86 - 1s - loss: 0.0012 - val_loss: 4.5504e-05 - 889ms/epoch - 10ms/step
# Epoch 51/100
# 86/86 - 1s - loss: 0.0012 - val_loss: 4.4963e-05 - 996ms/epoch - 12ms/step
# Epoch 52/100
# 86/86 - 1s - loss: 0.0011 - val_loss: 4.4330e-05 - 1s/epoch - 13ms/step
# Epoch 53/100
# 86/86 - 1s - loss: 0.0011 - val_loss: 4.3802e-05 - 880ms/epoch - 10ms/step
# Epoch 54/100
# 86/86 - 1s - loss: 9.9735e-04 - val_loss: 4.3193e-05 - 875ms/epoch - 10ms/step
# Epoch 55/100
# 86/86 - 1s - loss: 9.5656e-04 - val_loss: 4.2803e-05 - 881ms/epoch - 10ms/step
# Epoch 56/100
# 86/86 - 1s - loss: 9.0537e-04 - val_loss: 4.2206e-05 - 883ms/epoch - 10ms/step
# Epoch 57/100
# 86/86 - 1s - loss: 8.7404e-04 - val_loss: 4.1973e-05 - 877ms/epoch - 10ms/step
# Epoch 58/100
# 86/86 - 1s - loss: 8.2374e-04 - val_loss: 4.1295e-05 - 876ms/epoch - 10ms/step
# Epoch 59/100
# 86/86 - 1s - loss: 8.0432e-04 - val_loss: 4.1227e-05 - 881ms/epoch - 10ms/step
# Epoch 60/100
# 86/86 - 1s - loss: 7.5880e-04 - val_loss: 4.0507e-05 - 881ms/epoch - 10ms/step
# Epoch 61/100
# 86/86 - 1s - loss: 7.4589e-04 - val_loss: 4.0482e-05 - 879ms/epoch - 10ms/step
# Epoch 62/100
# 86/86 - 1s - loss: 7.1337e-04 - val_loss: 3.9938e-05 - 879ms/epoch - 10ms/step
# Epoch 63/100
# 86/86 - 1s - loss: 6.9664e-04 - val_loss: 3.9768e-05 - 878ms/epoch - 10ms/step
# Epoch 64/100
# 86/86 - 1s - loss: 6.8147e-04 - val_loss: 3.9389e-05 - 878ms/epoch - 10ms/step
# Epoch 65/100
# 86/86 - 1s - loss: 6.6623e-04 - val_loss: 3.9260e-05 - 874ms/epoch - 10ms/step
# Epoch 66/100
# 86/86 - 1s - loss: 6.5669e-04 - val_loss: 3.8963e-05 - 880ms/epoch - 10ms/step
# Epoch 67/100
# 86/86 - 1s - loss: 6.5538e-04 - val_loss: 3.8809e-05 - 890ms/epoch - 10ms/step
# Epoch 68/100
# 86/86 - 1s - loss: 6.4287e-04 - val_loss: 3.8537e-05 - 941ms/epoch - 11ms/step
# Epoch 69/100
# 86/86 - 1s - loss: 6.4735e-04 - val_loss: 3.8369e-05 - 925ms/epoch - 11ms/step
# Epoch 70/100
# 86/86 - 1s - loss: 6.4274e-04 - val_loss: 3.8244e-05 - 918ms/epoch - 11ms/step
# Epoch 71/100
# 86/86 - 1s - loss: 6.5040e-04 - val_loss: 3.8089e-05 - 901ms/epoch - 10ms/step
# Epoch 72/100
# 86/86 - 1s - loss: 6.5327e-04 - val_loss: 3.8051e-05 - 893ms/epoch - 10ms/step
# Epoch 73/100
# 86/86 - 1s - loss: 6.6402e-04 - val_loss: 3.7807e-05 - 913ms/epoch - 11ms/step
# Epoch 74/100
# 86/86 - 1s - loss: 6.6530e-04 - val_loss: 3.7872e-05 - 888ms/epoch - 10ms/step
# Epoch 75/100
# 86/86 - 1s - loss: 6.7215e-04 - val_loss: 3.7768e-05 - 886ms/epoch - 10ms/step
# Epoch 76/100
# 86/86 - 1s - loss: 6.8352e-04 - val_loss: 3.7659e-05 - 884ms/epoch - 10ms/step
# Epoch 77/100
# 86/86 - 1s - loss: 6.8858e-04 - val_loss: 3.7623e-05 - 884ms/epoch - 10ms/step
# Epoch 78/100
# 86/86 - 1s - loss: 6.9439e-04 - val_loss: 3.7349e-05 - 886ms/epoch - 10ms/step
# Epoch 79/100
# 86/86 - 1s - loss: 7.0263e-04 - val_loss: 3.7499e-05 - 885ms/epoch - 10ms/step
# Epoch 80/100
# 86/86 - 1s - loss: 7.3543e-04 - val_loss: 3.7478e-05 - 880ms/epoch - 10ms/step
# Epoch 81/100
# 86/86 - 1s - loss: 7.4343e-04 - val_loss: 3.7940e-05 - 882ms/epoch - 10ms/step
# Epoch 82/100
# 86/86 - 1s - loss: 7.7238e-04 - val_loss: 3.7751e-05 - 885ms/epoch - 10ms/step
# Epoch 83/100
# 86/86 - 1s - loss: 7.9126e-04 - val_loss: 3.7916e-05 - 883ms/epoch - 10ms/step
# Epoch 84/100
# 86/86 - 1s - loss: 7.8833e-04 - val_loss: 3.7532e-05 - 880ms/epoch - 10ms/step
# Epoch 85/100
# 86/86 - 1s - loss: 8.3025e-04 - val_loss: 3.8101e-05 - 883ms/epoch - 10ms/step
# Epoch 86/100
# 86/86 - 1s - loss: 8.3309e-04 - val_loss: 3.7913e-05 - 885ms/epoch - 10ms/step
# Epoch 87/100
# 86/86 - 1s - loss: 8.3830e-04 - val_loss: 3.7715e-05 - 885ms/epoch - 10ms/step
# Epoch 88/100
# 86/86 - 1s - loss: 8.4512e-04 - val_loss: 3.9195e-05 - 878ms/epoch - 10ms/step
# Epoch 89/100
# 86/86 - 1s - loss: 8.3908e-04 - val_loss: 3.8624e-05 - 885ms/epoch - 10ms/step
# Epoch 90/100
# 86/86 - 1s - loss: 8.3673e-04 - val_loss: 3.9648e-05 - 882ms/epoch - 10ms/step
# Epoch 91/100
# 86/86 - 1s - loss: 8.2448e-04 - val_loss: 3.8029e-05 - 883ms/epoch - 10ms/step
# Epoch 92/100
# 86/86 - 1s - loss: 8.0665e-04 - val_loss: 3.8632e-05 - 916ms/epoch - 11ms/step
# Epoch 93/100
# 86/86 - 1s - loss: 8.0565e-04 - val_loss: 3.7507e-05 - 883ms/epoch - 10ms/step
# Epoch 94/100
# 86/86 - 1s - loss: 7.9236e-04 - val_loss: 3.7949e-05 - 885ms/epoch - 10ms/step
# Epoch 95/100
# 86/86 - 1s - loss: 7.7438e-04 - val_loss: 3.7127e-05 - 886ms/epoch - 10ms/step
# Epoch 96/100
# 86/86 - 1s - loss: 7.6675e-04 - val_loss: 3.7242e-05 - 889ms/epoch - 10ms/step
# Epoch 97/100
# 86/86 - 1s - loss: 7.5349e-04 - val_loss: 3.6249e-05 - 875ms/epoch - 10ms/step
# Epoch 98/100
# 86/86 - 1s - loss: 7.3842e-04 - val_loss: 3.6251e-05 - 874ms/epoch - 10ms/step
# Epoch 99/100
# 86/86 - 1s - loss: 7.2004e-04 - val_loss: 3.5990e-05 - 877ms/epoch - 10ms/step
# Epoch 100/100
# 86/86 - 1s - loss: 6.8353e-04 - val_loss: 3.5474e-05 - 880ms/epoch - 10ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = model.predict(valid_X)
valid_X = valid_X.reshape((valid_X.shape[0], n_hours*n_features))
valid_X
# Out:
# 43/43 [==============================] - 0s 2ms/step
# array([[7.6645052e-01, 2.7534602e-02, 5.1315665e-02, ..., 1.4540792e-01,
#         1.4494085e-01, 1.4499354e-01],
#        [4.9253458e-01, 0.0000000e+00, 5.0806642e-02, ..., 1.5324366e-01,
#         1.5277719e-01, 1.5460467e-01],
#        [6.2463892e-01, 5.8965723e-04, 5.5058599e-02, ..., 1.6528702e-01,
#         1.6577649e-01, 1.6487408e-01],
#        ...,
#        [2.0228577e-01, 2.3041391e-03, 1.1114228e-01, ..., 8.4099889e-02,
#         8.4393263e-02, 8.4256887e-02],
#        [1.4823121e-01, 1.4994897e-01, 1.0303044e-01, ..., 8.4630609e-02,
#         8.4158301e-02, 8.4211707e-02],
#        [4.5266458e-01, 1.5610151e-02, 1.0450411e-01, ..., 8.8321328e-02,
#         8.8580847e-02, 8.7902665e-02]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = np.concatenate((valid_X[:, -(n_features-1):], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# %%
# invert scaling for actual
valid_y_new = valid_y.reshape((len(valid_y), 1))
inv_y = np.concatenate((valid_X[:, -(n_features-1):], valid_y_new), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 167.305

# %%
plt.figure(figsize=(15,9))
plt.grid(True)

plt.xlabel('Minute Observations')
plt.ylabel('Closing Price')
plt.plot(inv_yhat, label='BTC Predicted Price')
plt.plot(inv_y, label='BTC Actual Price')
plt.legend()

# %%
test_yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
test_X
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.5381673 , 0.26577356, 0.10589361, ..., 0.08623755, 0.08576524,
#         0.0864501 ],
#        [0.7091727 , 0.        , 0.10625732, ..., 0.08505857, 0.08498073,
#         0.08463955],
#        [0.7091727 , 0.07942534, 0.09281707, ..., 0.08284652, 0.08262718,
#         0.08242738],
#        ...,
#        [0.37863904, 0.7766648 , 0.40256393, ..., 0.39824808, 0.39780295,
#         0.39785254],
#        [0.7091727 , 0.9500315 , 0.4044541 , ..., 0.39697123, 0.39652598,
#         0.3965757 ],
#        [0.6979947 , 0.        , 0.40590513, ..., 0.40020669, 0.40157127,
#         0.3998114 ]], dtype=float32)

# %%
# invert scaling for forecast
test_inv_yhat = np.concatenate((test_X[:, -(n_features-1):], test_yhat), axis=1)
test_inv_yhat = scaler.inverse_transform(test_inv_yhat)
test_inv_yhat = test_inv_yhat[:,-1]

# %%
# invert scaling for actual
test_y_new = test_y.reshape((len(test_y), 1))
test_inv_y = np.concatenate((test_X[:, -(n_features-1):], test_y_new), axis=1)
test_inv_y = scaler.inverse_transform(test_inv_y)
test_inv_y = test_inv_y[:,-1]

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(test_inv_y, test_inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 156.407

# %%
plt.figure(figsize=(15,9))
plt.grid(True)

plt.xlabel('Minute Observations')
plt.ylabel('Closing Price')
plt.plot(test_inv_yhat, label='BTC Predicted Price')
plt.plot(test_inv_y, label='BTC Actual Price')
plt.legend()
